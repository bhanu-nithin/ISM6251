# %% [markdown]
# # ICP01 Jupyter Install
# ## Manne Bhanu Nithin Yadav

# %% [markdown]
# ![jupyter2.png](attachment:jupyter2.png)
#
# Hi, My name is Bhanu Nithin, I am from India, Telangana, Hyderabad.
# I am a current graduate student in University of South Florida.
# I have 15 months of work experience as a software engineer in Capgemini Hyderabad.

# %%
print("Hello World")
# Out:
# Hello World
