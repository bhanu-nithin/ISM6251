# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
df = pd.read_csv('C:/Users/Nithin Yadav/Desktop/DSPc02_dataset_1.csv')

df.head(3)
# Out:
#     input   target
# 0  116.24  3530.88
# 1   93.88  2187.91
# 2   94.72  3066.28

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# For educational purposes, let's look at the first five values in X and y (note how X is an array of lists)

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(X,y) # note the underscore. This is a convention to indicate that the output is not used.


# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X, lin_reg.predict(X), color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)

# %% [markdown]
# ... using fstring formatting, we can display these values as follows...

# %%
print(f"Y = {b0:.2f} + {b1:.2f}x")
print(f"R^2: {lin_reg.score(X, y):.3f}") 
# for more on fstrings see here...
# https://www.freecodecamp.org/news/python-f-strings-tutorial-how-to-use-f-strings-for-string-formatting/
# Out:
# Y = -28.95 + 31.17x
# R^2: 0.512

# %% [markdown]
# ## Conclusion
#
# As we can see the above model is not a good fit for the data because we can see the R^2 value is about 0.512. When the noise was not increased intially (value of standard deviation was 100) value of R^2 was 0.896. When the noise is increased which is the value of standard deviation is  increased by 190 (i.e 290) the value of R^2 was dropped by more than 0.3 which is 0.512 as shown above.
#
# From the above plot we can interpret that the blue line is not widely spread accross the plot as it is much more deviated from the model which clearly explains us that the model is not a correct fit for the data where we can say that noise plays an important role in fitting of the model.
